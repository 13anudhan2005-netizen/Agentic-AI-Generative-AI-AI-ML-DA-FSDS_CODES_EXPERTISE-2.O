# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mohur\\jupyter my work'

# %%
movie=pd.read_csv(r"Z:\9AM Data science\25 nov\Movie-Rating.csv")

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movie)
# Out:
# 559

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movie.index
# Out:
# RangeIndex(start=0, stop=559, step=1)

# %%
movie.info
# Out:
# <bound method DataFrame.info of                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movie['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movie.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movie.Film=movie.Film.astype('category')

# %%
movie.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movie.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: object

# %%
movie.Genre = movie.Genre.astype('category')
movie.Year = movie.Year.astype('category')

# %%
movie.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movie.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movie.info
# Out:
# <bound method DataFrame.info of                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# ...

# %%
movie.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movie.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = movie, x = 'CriticRating', y = 'AudienceRating', kind='hex')

# %%
j = sns.jointplot( data = movie, x = 'CriticRating', y = 'AudienceRating', kind='scatter')
plt.show()

# %%
sns.set_style('darkgrid')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
m2 = sns.distplot(movie.AudienceRating, bins = 15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
n1 = plt.hist(movie.AudienceRating, bins=15)

# %%
plt.hist(movie.BudgetMillions)
plt.show()

# %%
j = sns.jointplot(data=movie, x='CriticRating', y='AudienceRating', kind='hex')
plt.show()

# %%
j = sns.jointplot(data=movie, x='CriticRating', y='AudienceRating', kind='reg')
plt.show()

# %%
j = sns.jointplot(data=movie, x='CriticRating', y='AudienceRating', kind='kde')
plt.show()

# %%
j = sns.jointplot(data=movie, x='CriticRating', y='AudienceRating', kind='hist')
plt.show()

# %%
j = sns.jointplot(data=movie, x='CriticRating', y='AudienceRating', kind='resid')
plt.show()

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
import seaborn as sns

# %%
m7 = sns.distplot(movie.AudienceRating)
plt.show()

# %%
m1 = sns.distplot(movie.AudienceRating)
plt.show()

# %%
m = sns.distplot(movie.AudienceRating)
plt.show()

# %%
m1 = sns.distplot(movie.CriticRating)
plt.show()

# %%
m4= sns.distplot(movie.CriticRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m5 = sns.distplot(movie.AudienceRating, bins = 15)
plt.show()

# %%
m2 = sns.distplot(movie.AudienceRating, bins = 5)
plt.show()

# %%
n1 = plt.hist(movie.AudienceRating, bins=15)
plt.show()

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = plt.hist(movie.AudienceRating, bins=20)
plt.show()

# %%
sns.set_style('white') 
n1 = plt.hist(movie.AudienceRating, bins=20)
plt.show()

# %%
plt.hist(movie.BudgetMillions)
plt.show()

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %% [markdown]
# # Movies.Genre.unique()

# %%
plt.hist(movie[movie.Genre=='Action'].BudgetMillions, bins= 20)
plt.hist(movie[movie.Genre=='Thriller'].BudgetMillions, bins= 20)
plt.hist(movie[movie.Genre=='Drama'].BudgetMillions, bins= 20)
plt.show()

# %%
plt.hist(movie[movie.Genre=='Action'].BudgetMillions, bins= 20)
plt.hist(movie[movie.Genre=='Thriller'].BudgetMillions, bins= 20)
plt.hist(movie[movie.Genre=='Drama'].BudgetMillions, bins= 20)
plt.legend()
plt.show()

# %%
plt.hist([movie[movie.Genre == 'Action'].BudgetMillions,\
          movie[movie.Genre == 'Drama'].BudgetMillions, \
          movie[movie.Genre == 'Thriller'].BudgetMillions, \
          movie[movie.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
for gen in movie.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',\
                  fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',\
fit_reg=False, hue = 'Genre')
plt.show()

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',\
fit_reg=False, hue = 'Genre')
plt.show()

# %%
k1= sns.kdeplot(x=movie.CriticRating, y=movie.AudienceRating,
fill=False, cmap='mako')
plt.show()

# %%
k1= sns.kdeplot(x=movie.CriticRating, y=movie.AudienceRating,
fill=True, cmap='mako')
plt.show()

# %%
k1= sns.kdeplot(x=movie.CriticRating, y=movie.AudienceRating,
                fill=False,
                thresh=0.05,
                levels=19,
                cmap='Reds')
plt.show()

# %%
k1= sns.kdeplot(x=movie.CriticRating, y=movie.AudienceRating,
                fill=True,
                thresh=0.05,
                levels=19,
                cmap='Reds')
plt.show()

# %%
k1= sns.kdeplot(x=movie.CriticRating, y=movie.AudienceRating,
                fill=False,)
plt.show()

# %%
k1= sns.kdeplot(x=movie.CriticRating, y=movie.AudienceRating,
                fill=True,)
plt.show()

# %%
w1 = sns.boxplot(data=movie[movie.Genre == 'Drama'], x='Year', y = 'CriticRating')
plt.show()

# %%
sns.set_style('dark')
k1= sns.kdeplot(x=movie.BudgetMillions,
                y=movie.AudienceRating,
                fill=True, cmap='Greens_r'
               )
plt.show()

# %%
pip install --upgrade seaborn
# Out:
# ...
#
# ...

# %%
sns.jointplot( data=movie,
              x='BudgetMillions',
              y='AudienceRating',
              kind='kde',
              fill=True
)
plt.show()

# %%
axes
# Out:
# array([<Axes: >, <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>],
#       dtype=object)

# %%
w = sns.boxplot(data=movie, x='Genre', y = 'CriticRating')
plt.show()

# %%
z = sns.violinplot(data=movie, x='Genre', y = 'CriticRating') 
plt.show()

# %%
w1 = sns.boxplot(data=movie[movie.Genre == 'Drama'], x='Year', y = 'CriticRating')
plt.show()

# %%
plt.scatter(movie.CriticRating,movie.AudienceRating)

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' )
plt.show()

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions')
plt.show()

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws )
plt.show()
